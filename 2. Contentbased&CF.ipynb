# %% [markdown]
# # Mô hình gợi ý phim dựa trên nội dung.
#
# * Ở phần trước chúng ta đã tìm hiểu về tệp dữ liệu, các feature, và cũng đã tìm hiểu về đánh giá bộ phim theo thể loại bằng trọng số điểm đánh giá theo 1 công thức.
# * Tuy nhiên, ở phần này, chúng ta sẽ xây dựng một mô hình cụ thể hơn, sử dụng cosine_similarity để so sánh "độ gần gũi" (distance) của nó trên ma trận.
# * **Tóm lại:** Ở đây, sẽ là bắt đầu của bài xây dựng model gợi ý phim, nhưng ở phần đầu này, chúng ta sẽ xây dựng một model không train (nói cách khác, có thể coi là 1 công thức đơn giản) để đưa ra gợi ý, tuy nhiên, nó vẫn đóng góp 1 phần lớn cho xây dựng mô hình gợi ý của chúng bằng __SVD__ trong thư viện __surprise__

# %% [markdown]
# Ở phần đầu tiên này, chúng ta sẽ đi từ từ các bước, tìm hiểu feature có tính tác động cao, loại bỏ các feature không cần thiết khỏi dataframe, và đưa ra những tham số thủ công, đánh giá bằng kinh nghiệm và kiến thức cá nhân để cải thiên model, bởi vì model này không có các độ đo để đánh giá độ chính xác hay độ lệch. (accuracy, mae, etc)

# %%
import pandas as pd
import numpy as np
import warnings; warnings.simplefilter('ignore')

# %%
links_small = pd.read_csv('input_data/links_small.csv')
md = pd.read_csv('input_data/movies_metadata.csv')

# %%
# Tiền xử lý dữ liệu: lấy ra cột imdbId vì chúng ta sẽ sử dụng Id phim dựa trên tmdb
# Chỉ lấy giá trị không null
links_small = links_small[links_small['tmdbId'].notnull()]
links_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9112 entries, 0 to 9124
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9112 non-null   int64
#  1   imdbId   9112 non-null   int64
#  2   tmdbId   9112 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 284.8 KB

# %%
# convert sang int32 để đưa về 1 chuẩn chung, đang là float64
links_small= links_small['tmdbId'].astype('int')

# %%
links_small.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 9112 entries, 0 to 9124
# Series name: tmdbId
# Non-Null Count  Dtype
# --------------  -----
# 9112 non-null   int32
# dtypes: int32(1)
# memory usage: 106.8 KB

# %%
## Hàm để tiền xử lý

def convert_int(x):
    try:
        return int(x)
    except:
        return np.nan

# %%
#chuyển id về int32 để làm chuẩn
#Tìm kiếm id null rồi loại bỏ
md['id'] = md['id'].apply(convert_int)
md[md['id'].isnull()]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage  id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso... NaN       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o... NaN       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}] NaN       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 19730  ...            1     NaN     NaN              NaN    NaN      NaN
# 29503  ...           12     NaN     NaN              NaN    NaN      NaN
# 35587  ...           22     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 19730    NaN   NaN          NaN        NaN
# 29503    NaN   NaN          NaN        NaN
# 35587    NaN   NaN          NaN        NaN
#
# [3 rows x 24 columns]

# %%
md = md.drop([19730, 29503, 35587])

# %% [markdown]
# ## Trong tệp dữ liệu metadata về movie thì có 45000 phim, tuy nhiên chúng ta sẽ thực hiện mô hình của chúng ta chỉ trên những phim có trong links_small
#
# **Giải thích về điều này:**
# * Tệp dữ liệu 45k rất tạp nham, hơn những thế, có rất nhiều phim không bao giờ được biết đến, trong khi các hệ thống streaming phim hiện nay như netflix hoặc bất kì hệ thống nào, để có cơ chế mua bản quyền, những phim không đáng giá sẽ không bao giờ xuất hiện ở trên những hệ thống này, chính vì thế, tệp 9000 mục đích được tạo ra là đã có chọn lọc những phim đáng giá, đáng để đưa vào mô hình.
# * Mô hình của chúng ta ở bước hiện hiện tại (gợi ý phim dựa trên nội dung) là một mô hình không thông minh, nên chúng ta sẽ ưu tiên chất lượng trên hết.
# * **Kết luận:** ÍT NHẤT, ở mô hình này, chúng ta sẽ chỉ sử dụng tệp dữ liệu 9000 phim, và chúng ta sẽ thực hiện bước xử lý để lấy nó ra khỏi tệp dữ liệu lớn __movies_metadata.csv__

# %%
md['id'] = md['id'].astype('int')

# %%
# tạo dataframe mới để phục vụ cho model
smd = md[md['id'].isin(links_small)]
smd.shape
# Out:
# (9099, 24)

# %%
smd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9099 entries, 0 to 45265
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  9099 non-null   object
#  1   belongs_to_collection  1674 non-null   object
#  2   budget                 9099 non-null   object
#  3   genres                 9099 non-null   object
#  4   homepage               1974 non-null   object
#  5   id                     9099 non-null   int32
#  6   imdb_id                9099 non-null   object
#  7   original_language      9099 non-null   object
#  8   original_title         9099 non-null   object
#  9   overview               9087 non-null   object
#  10  popularity             9099 non-null   object
#  11  poster_path            9096 non-null   object
#  12  production_companies   9099 non-null   object
#  13  production_countries   9099 non-null   object
#  14  release_date           9099 non-null   object
#  15  revenue                9099 non-null   float64
#  16  runtime                9099 non-null   float64
#  17  spoken_languages       9099 non-null   object
#  18  status                 9097 non-null   object
#  19  tagline                7033 non-null   object
#  20  title                  9099 non-null   object
#  21  video                  9099 non-null   object
#  22  vote_average           9099 non-null   float64
#  23  vote_count             9099 non-null   float64
# dtypes: float64(4), int32(1), object(19)
# memory usage: 1.7+ MB

# %% [markdown]
# # Tiếp tục tiền xử lý dữ liệu, và chọn lọc features cần thiết thôi

# %%
smd = smd[['id','title','overview',
        'tagline','genres','vote_count',
        'vote_average','popularity','release_date']]
smd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9099 entries, 0 to 45265
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9099 non-null   int32
#  1   title         9099 non-null   object
#  2   overview      9087 non-null   object
#  3   tagline       7033 non-null   object
#  4   genres        9099 non-null   object
#  5   vote_count    9099 non-null   float64
#  6   vote_average  9099 non-null   float64
#  7   popularity    9099 non-null   object
#  8   release_date  9099 non-null   object
# dtypes: float64(2), int32(1), object(6)
# memory usage: 675.3+ KB

# %%
smd.isnull().sum()
# Out:
# id                 0
# title              0
# overview          12
# tagline         2066
# genres             0
# vote_count         0
# vote_average       0
# popularity         0
# release_date       0
# dtype: int64

# %% [markdown]
# Ở phần overview, có 12 giá trị null, để đảm bảo chất lượng cho mô hình ở giai đoạn này, chúng ta sẽ ưu tiêu bỏ nó đi, còn tagline thì không cần bỏ, overview quan trọng hơn.

# %%
smd[smd['overview'].isnull()].transpose()
# Out:
#                                                           300    \
# id                                                       161495
# title                                                 Roommates
# overview                                                    NaN
# tagline                                                     NaN
# genres        [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# vote_count                                                  7.0
# vote_average                                                6.4
# popularity                                             3.395867
# release_date                                         1995-03-01
#
#                                        641                          821    \
# id                                     10801                        48144
# title                          The Superwife  The Day the Sun Turned Cold
# overview                                 NaN                          NaN
# tagline                                  NaN                          NaN
# genres        [{'id': 35, 'name': 'Comedy'}]                           []
# vote_count                               7.0                          2.0
# vote_average                             5.3                          7.0
# popularity                          0.821299                     0.076062
# release_date                      1996-03-06                   1994-01-01
#
#                                                           1389   \
# id                                                        43775
# title                                              Guantanamera
# overview                                                    NaN
# tagline                                                     NaN
# genres        [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# vote_count                                                  3.0
# vote_average                                                8.0
# popularity                                             0.496315
# release_date                                         1995-01-01
#
#                       2194   \
# id                   134368
# title         One Tough Cop
# overview                NaN
# tagline                 NaN
# genres                   []
# vote_count              3.0
# vote_average            3.0
# popularity            1.082
# release_date     1998-10-09
#
#                                                           14123  \
# id                                                       140887
# title                                      The Three Musketeers
# overview                                                    NaN
# tagline                                                     NaN
# genres        [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# vote_count                                                  2.0
# vote_average                                                3.0
# popularity                                             0.694665
# release_date                                         1933-04-07
#
#                                                           18393  \
# id                                                       145594
# title                                             Descongelate!
# overview                                                    NaN
# tagline                                                     NaN
# genres        [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# vote_count                                                  0.0
# vote_average                                                0.0
# popularity                                             0.007517
# release_date                                         2003-09-12
#
#                                       26132  \
# id                                     3539
# title                              Off Beat
# overview                                NaN
# tagline                                 NaN
# genres        [{'id': 18, 'name': 'Drama'}]
# vote_count                             16.0
# vote_average                            6.5
# popularity                         1.149831
# release_date                     2004-09-11
#
#                                             31657  \
# id                                         284362
# title                     El vals de los inútiles
# overview                                      NaN
# tagline                                       NaN
# genres        [{'id': 99, 'name': 'Documentary'}]
# vote_count                                    3.0
# vote_average                                  5.7
# popularity                               0.120001
# release_date                           2014-05-08
#
#                                                           34619  \
# id                                                       332534
# title                                        Bana Masal Anlatma
# overview                                                    NaN
# tagline                                                     NaN
# genres        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# vote_count                                                  9.0
# vote_average                                                5.7
# popularity                                             1.095345
# release_date                                         2015-01-09
#
#                                                           34796  \
# id                                                       265351
# title                                              İtirazım Var
# overview                                                    NaN
# tagline                                                     NaN
# genres        [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# vote_count                                                  9.0
# vote_average                                                7.1
# popularity                                             0.465766
# release_date                                         2014-04-18
#
#                                                           34976
# id                                                       295748
# title                                               Pek Yakında
# overview                                                    NaN
# tagline                                                     NaN
# genres        [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# vote_count                                                 26.0
# vote_average                                                7.1
# popularity                                             2.088729
# release_date                                         2014-10-02

# %%
smd = smd.drop([300, 641, 821, 1389, 2194, 14123, 18393, 26132, 31657, 34619, 34796, 34976])

# %%
duplicate_rows = smd[smd.duplicated(subset=['id'], keep='first')]
# Lấy danh sách các id trùng lặp
duplicate_ids = duplicate_rows['id'].unique()
# Loại bỏ các dòng bị lặp từ DataFrame
smd = smd.drop_duplicates(subset=['id'], keep=False)
# In ra số hàng của DataFrame đã làm sạch
smd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9053 entries, 0 to 40503
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9053 non-null   int32
#  1   title         9053 non-null   object
#  2   overview      9053 non-null   object
#  3   tagline       7021 non-null   object
#  4   genres        9053 non-null   object
#  5   vote_count    9053 non-null   float64
#  6   vote_average  9053 non-null   float64
#  7   popularity    9053 non-null   object
#  8   release_date  9053 non-null   object
# dtypes: float64(2), int32(1), object(6)
# memory usage: 671.9+ KB

# %%
smd.transpose()
# Out:
#                                                           0      \
# id                                                          862
# title                                                 Toy Story
# overview      Led by Woody, Andy's toys live happily in his ...
# tagline                                                     NaN
# genres        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# vote_count                                               5415.0
# vote_average                                                7.7
# popularity                                            21.946943
# release_date                                         1995-10-30
#
#                                                           1      \
# id                                                         8844
# title                                                   Jumanji
# overview      When siblings Judy and Peter discover an encha...
# tagline               Roll the dice and unleash the excitement!
# genres        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# vote_count                                               2413.0
# vote_average                                                6.9
# popularity                                            17.015539
# release_date                                         1995-12-15
#
#                                                           2      \
# id                                                        15602
# title                                          Grumpier Old Men
# overview      A family wedding reignites the ancient feud be...
# tagline       Still Yelling. Still Fighting. Still Ready for...
# genres        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# vote_count                                                 92.0
# vote_average                                                6.5
# popularity                                              11.7129
# release_date                                         1995-12-22
#
#                                                           3      \
# id                                                        31357
# title                                         Waiting to Exhale
# overview      Cheated on, mistreated and stepped on, the wom...
# tagline       Friends are the people who let you be yourself...
# genres        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# vote_count                                                 34.0
# vote_average                                                6.1
# popularity                                             3.859495
# release_date                                         1995-12-22
#
#                                                           4      \
# id                                                        11862
# title                               Father of the Bride Part II
# overview      Just when George Banks has recovered from his ...
# tagline       Just When His World Is Back To Normal... He's ...
# genres                           [{'id': 35, 'name': 'Comedy'}]
# vote_count                                                173.0
# vote_average                                                5.7
# popularity                                             8.387519
# release_date                                         1995-02-10
#
#                                                           5      \
# id                                                          949
# title                                                      Heat
# overview      Obsessive master thief, Neil McCauley leads a ...
# tagline                                A Los Angeles Crime Saga
# genres        [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# vote_count                                               1886.0
# vote_average                                                7.7
# popularity                                            17.924927
# release_date                                         1995-12-15
#
#                                                           6      \
# id                                                        11860
# title                                                   Sabrina
# overview      An ugly duckling having undergone a remarkable...
# tagline       You are cordially invited to the most surprisi...
# genres        [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# vote_count                                                141.0
# vote_average                                                6.2
# popularity                                             6.677277
# release_date                                         1995-12-15
#
#                                                           7      \
# id                                                        45325
# title                                              Tom and Huck
# overview      A mischievous young boy, Tom Sawyer, witnesses...
# tagline                                  The Original Bad Boys.
# genres        [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# vote_count                                                 45.0
# vote_average                                                5.4
# popularity                                             2.561161
# release_date                                         1995-12-22
#
#                                                           8      \
# id                                                         9091
# title                                              Sudden Death
# overview      International action superstar Jean Claude Van...
# tagline                              Terror goes into overtime.
# genres        [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# vote_count                                                174.0
# vote_average                                                5.5
# popularity                                              5.23158
# release_date                                         1995-12-22
#
#                                                           9      ...  \
# id                                                          710  ...
# title                                                 GoldenEye  ...
# overview      James Bond must unmask the mysterious head of ...  ...
# tagline                    No limits. No fears. No substitutes.  ...
# genres        [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  ...
# vote_count                                               1194.0  ...
# vote_average                                                6.6  ...
# popularity                                            14.686036  ...
# release_date                                         1995-11-16  ...
#
#                                                           39619  \
# id                                                       373348
# title                                Author: The JT LeRoy Story
# overview      New York magazine’s October 2005 issue sent sh...
# tagline                                                     NaN
# genres                      [{'id': 99, 'name': 'Documentary'}]
# vote_count                                                  9.0
# vote_average                                                6.2
# popularity                                             0.428899
# release_date                                         2016-01-22
#
#                                                           39663  \
# id                                                       338766
# title                                        Hell or High Water
# overview      A divorced dad and his ex-con brother resort t...
# tagline                             Blood always follows money.
# genres        [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# vote_count                                               1304.0
# vote_average                                                7.2
# popularity                                            12.565896
# release_date                                         2016-08-12
#
#                                                           39669  \
# id                                                       390734
# title                             Kingsglaive: Final Fantasy XV
# overview      The magical kingdom of Lucis is home to the wo...
# tagline                           Kingsglaive: Final Fantasy XV
# genres        [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# vote_count                                                201.0
# vote_average                                                6.8
# popularity                                             7.692445
# release_date                                         2016-07-09
#
#                                                           39752  \
# id                                                       314420
# title                                                      Body
# overview      A night out turns deadly when three girls brea...
# tagline                                                     NaN
# genres        [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# vote_count                                                 16.0
# vote_average                                                5.0
# popularity                                             6.236714
# release_date                                         2015-01-25
#
#                                                           39771  \
# id                                                       390989
# title                              Sharknado 4: The 4th Awakens
# overview      The new installment of the Sharknado franchise...
# tagline       What happens in Vegas, stays in Vegas. Unless ...
# genres        [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# vote_count                                                 88.0
# vote_average                                                4.3
# popularity                                             4.574494
# release_date                                         2016-07-31
#
#                                                           39784  \
# id                                                       159550
# title                            The Last Brickmaker in America
# overview      A man must cope with the loss of his wife and ...
# tagline                                                     NaN
# genres                            [{'id': 18, 'name': 'Drama'}]
# vote_count                                                  1.0
# vote_average                                                7.0
# popularity                                             0.038998
# release_date                                         2001-09-23
#
#                                                           40004  \
# id                                                       392572
# title                                                    Rustom
# overview      Rustom Pavri, an honourable officer of the Ind...
# tagline       Decorated Officer. Devoted Family Man. Defendi...
# genres        [{'id': 53, 'name': 'Thriller'}, {'id': 10749,...
# vote_count                                                 25.0
# vote_average                                                7.3
# popularity                                             7.333139
# release_date                                         2016-08-12
#
#                                                           40058  \
# id                                                       402672
# title                                              Mohenjo Daro
# overview      Village lad Sarman is drawn to big, bad Mohenj...
# tagline                                                     NaN
# genres        [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# vote_count                                                 26.0
# vote_average                                                6.7
# popularity                                             1.423358
# release_date                                         2016-08-11
#
#                                                           40224  \
# id                                                       315011
# title                                             Shin Godzilla
# overview      From the mind behind Evangelion comes a hit la...
# tagline                         A god incarnate. A city doomed.
# genres        [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# vote_count                                                152.0
# vote_average                                                6.6
# popularity                                             9.285519
# release_date                                         2016-07-29
#
#                                                           40503
# id                                                       391698
# title         The Beatles: Eight Days a Week - The Touring Y...
# overview      The band stormed Europe in 1963, and, in 1964,...
# tagline                 The band you know. The story you don't.
# genres        [{'id': 99, 'name': 'Documentary'}, {'id': 104...
# vote_count                                                 92.0
# vote_average                                                7.6
# popularity                                             7.078301
# release_date                                         2016-09-15
#
# [9 rows x 9053 columns]

# %%
from ast import literal_eval
#Tiền xử lý cột genres (thể loại phim)
#Thay thế các giá trị NaN trong cột 'genres' bằng chuỗi '[]'.
#Còn các chuỗi Json được chuyển thành các đối tượng Python(dictionary).
smd['genres'] = smd['genres'].fillna('[]').apply(literal_eval)
#Trích xuất giá trị của khóa 'name' từ dictionary về kiểu danh sách (list)
smd['genres'] = smd['genres'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
smd['genres']
# Out:
# 0                              [Animation, Comedy, Family]
# 1                             [Adventure, Fantasy, Family]
# 2                                        [Romance, Comedy]
# 3                                 [Comedy, Drama, Romance]
# 4                                                 [Comedy]
#                                ...
# 39784                                              [Drama]
# 40004                                  [Thriller, Romance]
# 40058                 [Adventure, Drama, History, Romance]
# 40224    [Action, Adventure, Drama, Horror, Science Fic...
# 40503                                 [Documentary, Music]
# Name: genres, Length: 9053, dtype: object

# %%
# Tiền xử lý dữ liệu để lấy được ra được thông tin year bằng split bằng '-'

smd['year'] = pd.to_datetime(smd['release_date'], errors='coerce').apply(
    lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
smd = smd.drop(columns=['release_date'])

# %%
smd.transpose()
# Out:
#                                                           0      \
# id                                                          862
# title                                                 Toy Story
# overview      Led by Woody, Andy's toys live happily in his ...
# tagline                                                     NaN
# genres                              [Animation, Comedy, Family]
# vote_count                                               5415.0
# vote_average                                                7.7
# popularity                                            21.946943
# year                                                       1995
#
#                                                           1      \
# id                                                         8844
# title                                                   Jumanji
# overview      When siblings Judy and Peter discover an encha...
# tagline               Roll the dice and unleash the excitement!
# genres                             [Adventure, Fantasy, Family]
# vote_count                                               2413.0
# vote_average                                                6.9
# popularity                                            17.015539
# year                                                       1995
#
#                                                           2      \
# id                                                        15602
# title                                          Grumpier Old Men
# overview      A family wedding reignites the ancient feud be...
# tagline       Still Yelling. Still Fighting. Still Ready for...
# genres                                        [Romance, Comedy]
# vote_count                                                 92.0
# vote_average                                                6.5
# popularity                                              11.7129
# year                                                       1995
#
#                                                           3      \
# id                                                        31357
# title                                         Waiting to Exhale
# overview      Cheated on, mistreated and stepped on, the wom...
# tagline       Friends are the people who let you be yourself...
# genres                                 [Comedy, Drama, Romance]
# vote_count                                                 34.0
# vote_average                                                6.1
# popularity                                             3.859495
# year                                                       1995
#
#                                                           4      \
# id                                                        11862
# title                               Father of the Bride Part II
# overview      Just when George Banks has recovered from his ...
# tagline       Just When His World Is Back To Normal... He's ...
# genres                                                 [Comedy]
# vote_count                                                173.0
# vote_average                                                5.7
# popularity                                             8.387519
# year                                                       1995
#
#                                                           5      \
# id                                                          949
# title                                                      Heat
# overview      Obsessive master thief, Neil McCauley leads a ...
# tagline                                A Los Angeles Crime Saga
# genres                         [Action, Crime, Drama, Thriller]
# vote_count                                               1886.0
# vote_average                                                7.7
# popularity                                            17.924927
# year                                                       1995
#
#                                                           6      \
# id                                                        11860
# title                                                   Sabrina
# overview      An ugly duckling having undergone a remarkable...
# tagline       You are cordially invited to the most surprisi...
# genres                                        [Comedy, Romance]
# vote_count                                                141.0
# vote_average                                                6.2
# popularity                                             6.677277
# year                                                       1995
#
#                                                           7      \
# id                                                        45325
# title                                              Tom and Huck
# overview      A mischievous young boy, Tom Sawyer, witnesses...
# tagline                                  The Original Bad Boys.
# genres                       [Action, Adventure, Drama, Family]
# vote_count                                                 45.0
# vote_average                                                5.4
# popularity                                             2.561161
# year                                                       1995
#
#                                                           8      \
# id                                                         9091
# title                                              Sudden Death
# overview      International action superstar Jean Claude Van...
# tagline                              Terror goes into overtime.
# genres                            [Action, Adventure, Thriller]
# vote_count                                                174.0
# vote_average                                                5.5
# popularity                                              5.23158
# year                                                       1995
#
#                                                           9      ...  \
# id                                                          710  ...
# title                                                 GoldenEye  ...
# overview      James Bond must unmask the mysterious head of ...  ...
# tagline                    No limits. No fears. No substitutes.  ...
# genres                            [Adventure, Action, Thriller]  ...
# vote_count                                               1194.0  ...
# vote_average                                                6.6  ...
# popularity                                            14.686036  ...
# year                                                       1995  ...
#
#                                                           39619  \
# id                                                       373348
# title                                Author: The JT LeRoy Story
# overview      New York magazine’s October 2005 issue sent sh...
# tagline                                                     NaN
# genres                                            [Documentary]
# vote_count                                                  9.0
# vote_average                                                6.2
# popularity                                             0.428899
# year                                                       2016
#
#                                                           39663  \
# id                                                       338766
# title                                        Hell or High Water
# overview      A divorced dad and his ex-con brother resort t...
# tagline                             Blood always follows money.
# genres                        [Crime, Drama, Thriller, Western]
# vote_count                                               1304.0
# vote_average                                                7.2
# popularity                                            12.565896
# year                                                       2016
#
#                                                           39669  \
# id                                                       390734
# title                             Kingsglaive: Final Fantasy XV
# overview      The magical kingdom of Lucis is home to the wo...
# tagline                           Kingsglaive: Final Fantasy XV
# genres        [Action, Animation, Adventure, Drama, Fantasy,...
# vote_count                                                201.0
# vote_average                                                6.8
# popularity                                             7.692445
# year                                                       2016
#
#                                                           39752  \
# id                                                       314420
# title                                                      Body
# overview      A night out turns deadly when three girls brea...
# tagline                                                     NaN
# genres                                        [Drama, Thriller]
# vote_count                                                 16.0
# vote_average                                                5.0
# popularity                                             6.236714
# year                                                       2015
#
#                                                           39771  \
# id                                                       390989
# title                              Sharknado 4: The 4th Awakens
# overview      The new installment of the Sharknado franchise...
# tagline       What happens in Vegas, stays in Vegas. Unless ...
# genres                        [Comedy, Horror, Science Fiction]
# vote_count                                                 88.0
# vote_average                                                4.3
# popularity                                             4.574494
# year                                                       2016
#
#                                                           39784  \
# id                                                       159550
# title                            The Last Brickmaker in America
# overview      A man must cope with the loss of his wife and ...
# tagline                                                     NaN
# genres                                                  [Drama]
# vote_count                                                  1.0
# vote_average                                                7.0
# popularity                                             0.038998
# year                                                       2001
#
#                                                           40004  \
# id                                                       392572
# title                                                    Rustom
# overview      Rustom Pavri, an honourable officer of the Ind...
# tagline       Decorated Officer. Devoted Family Man. Defendi...
# genres                                      [Thriller, Romance]
# vote_count                                                 25.0
# vote_average                                                7.3
# popularity                                             7.333139
# year                                                       2016
#
#                                                           40058  \
# id                                                       402672
# title                                              Mohenjo Daro
# overview      Village lad Sarman is drawn to big, bad Mohenj...
# tagline                                                     NaN
# genres                     [Adventure, Drama, History, Romance]
# vote_count                                                 26.0
# vote_average                                                6.7
# popularity                                             1.423358
# year                                                       2016
#
#                                                           40224  \
# id                                                       315011
# title                                             Shin Godzilla
# overview      From the mind behind Evangelion comes a hit la...
# tagline                         A god incarnate. A city doomed.
# genres        [Action, Adventure, Drama, Horror, Science Fic...
# vote_count                                                152.0
# vote_average                                                6.6
# popularity                                             9.285519
# year                                                       2016
#
#                                                           40503
# id                                                       391698
# title         The Beatles: Eight Days a Week - The Touring Y...
# overview      The band stormed Europe in 1963, and, in 1964,...
# tagline                 The band you know. The story you don't.
# genres                                     [Documentary, Music]
# vote_count                                                 92.0
# vote_average                                                7.6
# popularity                                             7.078301
# year                                                       2016
#
# [9 rows x 9053 columns]

# %% [markdown]
# # Mô hình gợi ý phim dựa trên nội dung(1): Sử dụng mô tả và tagline của phim

# %% [markdown]
# ## Trước tiên, chúng ta muốn xây dựng hệ thống mà sử dụng mô tả (overview + taglines)

# %% [markdown]
# `CountVectorizer` và `TfidfVectorizer` là hai công cụ phổ biến trong xử lý văn bản trong Machine Learning và Natural Language Processing (NLP). Dưới đây là sự khác biệt chính giữa chúng:
#
# 1. **CountVectorizer**:
#    - Chuyển đổi một tập hợp các văn bản thành ma trận số lần xuất hiện của các từ trong các văn bản đó (tần suất xuất hiện).
#    - Giá trị của mỗi ô trong ma trận là số lần xuất hiện của từ trong văn bản tương ứng.
#    - Không xử lý trọng số hoặc tần suất xuất hiện của từng từ trong văn bản.
#
# 2. **TfidfVectorizer** (Term Frequency-Inverse Document Frequency):
#    - Tính toán trọng số của mỗi từ trong một tập hợp các văn bản dựa trên tần suất xuất hiện của từ đó trong mỗi văn bản cộng với mức độ quan trọng của từ đó trong tất cả các văn bản.
#    - Cân nhắc tần suất xuất hiện của từ trong một văn bản cụ thể (TF), cùng với tần suất xuất hiện của từ đó trong toàn bộ tập hợp các văn bản (IDF).
#    - Giá trị của mỗi ô trong ma trận là giá trị TF-IDF của từng từ trong văn bản.

# %% [markdown]
# Hãy giải thích các tham số trong `TfidfVectorizer`:
#
# 1. **analyzer='word'**: Tham số này chỉ định phương pháp phân tích các đơn vị văn bản. Trong trường hợp này, 'word' chỉ ra rằng các đơn vị văn bản được xem xét là các từ riêng lẻ.
#
# 2. **ngram_range=(1, 2)**: Tham số này chỉ định phạm vi của các n-gram mà bạn muốn sử dụng. Trong trường hợp này, `(1, 2)` chỉ ra rằng các unigram (1-gram) và bigram (2-gram) sẽ được xem xét.
#
# 3. **min_df=0.0000000001**: Tham số này chỉ định ngưỡng tần suất tối thiểu của một từ để được tính trong vector của văn bản. Trong trường hợp này, giá trị là 0.0000000001, tức là bất kỳ từ nào xuất hiện ít nhất một lần trong toàn bộ tập dữ liệu sẽ được tính vào vector.
#
# 4. **stop_words='english'**: Tham số này chỉ định danh sách các từ dừng (stop words) mà bạn muốn loại bỏ khỏi văn bản. Trong trường hợp này, 'english' chỉ ra rằng danh sách từ dừng được sử dụng là danh sách từ dừng tiếng Anh được tích hợp sẵn trong scikit-learn.
#
# Về câu hỏi vì sao `min_df` không được đặt bằng 0, điều này là do `min_df` xác định ngưỡng tần suất tối thiểu của một từ để được tính trong vector của văn bản. Nếu đặt `min_df=0`, nó có nghĩa là mọi từ đều được tính vào vector, bất kể tần suất xuất hiện của chúng. Điều này có thể dẫn đến các từ rất phổ biến và ít thông tin (ví dụ: từ dừng) chiếm quá nhiều không gian trong vector và ảnh hưởng đến hiệu suất của mô hình. Để tránh điều này, chúng ta thường đặt `min_df` thành một giá trị nhỏ, như `min_df=0.0000000001`, như trong trường hợp này.

# %%
smd['tagline'] = smd['tagline'].fillna('')
smd['description'] = smd['overview'] + smd['tagline']
smd['description'] = smd['description'].fillna('')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0.0000000001, stop_words='english')
tfidf_matrix = tf.fit_transform(smd['description'])

# %%
tfidf_matrix.shape
# Out:
# (9053, 267555)

# %% [markdown]
# 1. **Sử dụng TF-IDF Vectorizer**: Khi sử dụng `TF-IDF Vectorizer` để biểu diễn các văn bản, chúng ta thu được một ma trận các vectơ, trong đó mỗi vectơ biểu diễn một văn bản và mỗi phần tử trong vectơ biểu diễn một từ hoặc n-gram và có giá trị tương ứng với trọng số TF-IDF của từ hoặc n-gram đó trong văn bản.
#
# 2. **Tính toán Độ tương đồng Cosine**: Độ tương đồng cosine là một phép đo độ tương đồng giữa hai vectơ trong không gian nhiều chiều. Trong trường hợp này, các vectơ biểu diễn các văn bản trong không gian các từ hoặc n-gram. Độ tương đồng cosine giữa hai văn bản được tính bằng cách lấy tích vô hướng của hai vectơ biểu diễn hai văn bản và chia cho tích của độ dài của hai vectơ đó.
#
# 3. **Sử dụng `linear_kernel` thay vì `cosine_similarities`**: `linear_kernel` là một hàm trong scikit-learn được sử dụng để tính toán tích vô hướng giữa các vectơ. Trong trường hợp này, chúng ta không cần phải sử dụng `cosine_similarities` để tính toán độ tương đồng cosine, mà có thể sử dụng trực tiếp `linear_kernel`. Việc này tiết kiệm thời gian tính toán vì `linear_kernel` được cài đặt để tận dụng hiệu quả các tính chất của tích vô hướng trong không gian vector.
#
# Vì vậy, ý nghĩa của câu này là khi sử dụng `TF-IDF Vectorizer` để biểu diễn văn bản, việc tính toán độ tương đồng cosine giữa các văn bản có thể được thực hiện một cách nhanh chóng bằng cách sử dụng `linear_kernel` thay vì `cosine_similarities`.

# %%
# http://scikit-learn.org/stable/modules/metrics.html#linear-kernel
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim[0:5]
# Out:
# array([[1.        , 0.00680015, 0.        , ..., 0.        , 0.        ,
#         0.00477555],
#        [0.00680015, 1.        , 0.01530131, ..., 0.        , 0.00175585,
#         0.0036893 ],
#        [0.        , 0.01530131, 1.        , ..., 0.0019266 , 0.00221451,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.00224727, 0.00789369, ..., 0.        , 0.00380764,
#         0.0018776 ]])

# %% [markdown]
# * Giờ chúng ta đã có được ma trận độ tương đồng giữa tất cả các cặp phim trong dataset.
# * Tiếp theo là viết 1 hàm để trả về 30 bộ phim gần nhất cho 1 bộ phim cụ thể, dựa trên điểm tương đồng cosine.

# %%
smd = smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])

# %%
smd = smd.drop(columns=['index'])

# %%
smd.transpose()
# Out:
#                                                            0     \
# id                                                          862
# title                                                 Toy Story
# overview      Led by Woody, Andy's toys live happily in his ...
# tagline
# genres                              [Animation, Comedy, Family]
# vote_count                                               5415.0
# vote_average                                                7.7
# popularity                                            21.946943
# year                                                       1995
# description   Led by Woody, Andy's toys live happily in his ...
#
#                                                            1     \
# id                                                         8844
# title                                                   Jumanji
# overview      When siblings Judy and Peter discover an encha...
# tagline               Roll the dice and unleash the excitement!
# genres                             [Adventure, Fantasy, Family]
# vote_count                                               2413.0
# vote_average                                                6.9
# popularity                                            17.015539
# year                                                       1995
# description   When siblings Judy and Peter discover an encha...
#
#                                                            2     \
# id                                                        15602
# title                                          Grumpier Old Men
# overview      A family wedding reignites the ancient feud be...
# tagline       Still Yelling. Still Fighting. Still Ready for...
# genres                                        [Romance, Comedy]
# vote_count                                                 92.0
# vote_average                                                6.5
# popularity                                              11.7129
# year                                                       1995
# description   A family wedding reignites the ancient feud be...
#
#                                                            3     \
# id                                                        31357
# title                                         Waiting to Exhale
# overview      Cheated on, mistreated and stepped on, the wom...
# tagline       Friends are the people who let you be yourself...
# genres                                 [Comedy, Drama, Romance]
# vote_count                                                 34.0
# vote_average                                                6.1
# popularity                                             3.859495
# year                                                       1995
# description   Cheated on, mistreated and stepped on, the wom...
#
#                                                            4     \
# id                                                        11862
# title                               Father of the Bride Part II
# overview      Just when George Banks has recovered from his ...
# tagline       Just When His World Is Back To Normal... He's ...
# genres                                                 [Comedy]
# vote_count                                                173.0
# vote_average                                                5.7
# popularity                                             8.387519
# year                                                       1995
# description   Just when George Banks has recovered from his ...
#
#                                                            5     \
# id                                                          949
# title                                                      Heat
# overview      Obsessive master thief, Neil McCauley leads a ...
# tagline                                A Los Angeles Crime Saga
# genres                         [Action, Crime, Drama, Thriller]
# vote_count                                               1886.0
# vote_average                                                7.7
# popularity                                            17.924927
# year                                                       1995
# description   Obsessive master thief, Neil McCauley leads a ...
#
#                                                            6     \
# id                                                        11860
# title                                                   Sabrina
# overview      An ugly duckling having undergone a remarkable...
# tagline       You are cordially invited to the most surprisi...
# genres                                        [Comedy, Romance]
# vote_count                                                141.0
# vote_average                                                6.2
# popularity                                             6.677277
# year                                                       1995
# description   An ugly duckling having undergone a remarkable...
#
#                                                            7     \
# id                                                        45325
# title                                              Tom and Huck
# overview      A mischievous young boy, Tom Sawyer, witnesses...
# tagline                                  The Original Bad Boys.
# genres                       [Action, Adventure, Drama, Family]
# vote_count                                                 45.0
# vote_average                                                5.4
# popularity                                             2.561161
# year                                                       1995
# description   A mischievous young boy, Tom Sawyer, witnesses...
#
#                                                            8     \
# id                                                         9091
# title                                              Sudden Death
# overview      International action superstar Jean Claude Van...
# tagline                              Terror goes into overtime.
# genres                            [Action, Adventure, Thriller]
# vote_count                                                174.0
# vote_average                                                5.5
# popularity                                              5.23158
# year                                                       1995
# description   International action superstar Jean Claude Van...
#
#                                                            9     ...  \
# id                                                          710  ...
# title                                                 GoldenEye  ...
# overview      James Bond must unmask the mysterious head of ...  ...
# tagline                    No limits. No fears. No substitutes.  ...
# genres                            [Adventure, Action, Thriller]  ...
# vote_count                                               1194.0  ...
# vote_average                                                6.6  ...
# popularity                                            14.686036  ...
# year                                                       1995  ...
# description   James Bond must unmask the mysterious head of ...  ...
#
#                                                            9043  \
# id                                                       373348
# title                                Author: The JT LeRoy Story
# overview      New York magazine’s October 2005 issue sent sh...
# tagline
# genres                                            [Documentary]
# vote_count                                                  9.0
# vote_average                                                6.2
# popularity                                             0.428899
# year                                                       2016
# description   New York magazine’s October 2005 issue sent sh...
#
#                                                            9044  \
# id                                                       338766
# title                                        Hell or High Water
# overview      A divorced dad and his ex-con brother resort t...
# tagline                             Blood always follows money.
# genres                        [Crime, Drama, Thriller, Western]
# vote_count                                               1304.0
# vote_average                                                7.2
# popularity                                            12.565896
# year                                                       2016
# description   A divorced dad and his ex-con brother resort t...
#
#                                                            9045  \
# id                                                       390734
# title                             Kingsglaive: Final Fantasy XV
# overview      The magical kingdom of Lucis is home to the wo...
# tagline                           Kingsglaive: Final Fantasy XV
# genres        [Action, Animation, Adventure, Drama, Fantasy,...
# vote_count                                                201.0
# vote_average                                                6.8
# popularity                                             7.692445
# year                                                       2016
# description   The magical kingdom of Lucis is home to the wo...
#
#                                                            9046  \
# id                                                       314420
# title                                                      Body
# overview      A night out turns deadly when three girls brea...
# tagline
# genres                                        [Drama, Thriller]
# vote_count                                                 16.0
# vote_average                                                5.0
# popularity                                             6.236714
# year                                                       2015
# description   A night out turns deadly when three girls brea...
#
#                                                            9047  \
# id                                                       390989
# title                              Sharknado 4: The 4th Awakens
# overview      The new installment of the Sharknado franchise...
# tagline       What happens in Vegas, stays in Vegas. Unless ...
# genres                        [Comedy, Horror, Science Fiction]
# vote_count                                                 88.0
# vote_average                                                4.3
# popularity                                             4.574494
# year                                                       2016
# description   The new installment of the Sharknado franchise...
#
#                                                            9048  \
# id                                                       159550
# title                            The Last Brickmaker in America
# overview      A man must cope with the loss of his wife and ...
# tagline
# genres                                                  [Drama]
# vote_count                                                  1.0
# vote_average                                                7.0
# popularity                                             0.038998
# year                                                       2001
# description   A man must cope with the loss of his wife and ...
#
#                                                            9049  \
# id                                                       392572
# title                                                    Rustom
# overview      Rustom Pavri, an honourable officer of the Ind...
# tagline       Decorated Officer. Devoted Family Man. Defendi...
# genres                                      [Thriller, Romance]
# vote_count                                                 25.0
# vote_average                                                7.3
# popularity                                             7.333139
# year                                                       2016
# description   Rustom Pavri, an honourable officer of the Ind...
#
#                                                            9050  \
# id                                                       402672
# title                                              Mohenjo Daro
# overview      Village lad Sarman is drawn to big, bad Mohenj...
# tagline
# genres                     [Adventure, Drama, History, Romance]
# vote_count                                                 26.0
# vote_average                                                6.7
# popularity                                             1.423358
# year                                                       2016
# description   Village lad Sarman is drawn to big, bad Mohenj...
#
#                                                            9051  \
# id                                                       315011
# title                                             Shin Godzilla
# overview      From the mind behind Evangelion comes a hit la...
# tagline                         A god incarnate. A city doomed.
# genres        [Action, Adventure, Drama, Horror, Science Fic...
# vote_count                                                152.0
# vote_average                                                6.6
# popularity                                             9.285519
# year                                                       2016
# description   From the mind behind Evangelion comes a hit la...
#
#                                                            9052
# id                                                       391698
# title         The Beatles: Eight Days a Week - The Touring Y...
# overview      The band stormed Europe in 1963, and, in 1964,...
# tagline                 The band you know. The story you don't.
# genres                                     [Documentary, Music]
# vote_count                                                 92.0
# vote_average                                                7.6
# popularity                                             7.078301
# year                                                       2016
# description   The band stormed Europe in 1963, and, in 1964,...
#
# [10 rows x 9053 columns]

# %%
def get_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %% [markdown]
# * Đã xong kiểu mẫu ban đầu!
# * Giờ chúng ta sẽ thử đưa ra một vài yêu cầu để xem mô hình hoạt động đến đâu

# %%
get_recommendations('Wolf Children').head(10)
# Out:
# 3178                         Bounce
# 1729    I Married a Strange Person!
# 6743    I Could Never Be Your Woman
# 2873                          Loser
# 2804                     Parenthood
# 3044             Autumn in New York
# 5966                In Good Company
# 5358                        College
# 4372                  About Schmidt
# 8920              The Men Next Door
# Name: title, dtype: object

# %%
get_recommendations('Castle in the Sky').head(10)
# Out:
# 1687                         The Dark Crystal
# 8325           Percy Jackson: Sea of Monsters
# 5553    Sky Captain and the World of Tomorrow
# 6154                                  Stealth
# 652                                Phenomenon
# 115                            Pie in the Sky
# 6249                           Chicken Little
# 5114                        Home on the Range
# 7062                                     Igor
# 2829                      The Virgin Suicides
# Name: title, dtype: object

# %%
get_recommendations('Finding Nemo').head(10)
# Out:
# 9016                              Finding Dory
# 5569                                Shark Tale
# 2732          Teenage Mutant Ninja Turtles III
# 4233                 The Incredible Mr. Limpet
# 7544                                Mr. Nobody
# 2702                              Turtle Diary
# 814               20,000 Leagues Under the Sea
# 5348                             Arizona Dream
# 2232    Little Nemo: Adventures In Slumberland
# 2568              Fast Times at Ridgemont High
# Name: title, dtype: object

# %%
get_recommendations('Neon Genesis Evangelion: Death and Rebirth').head(10)
# Out:
# 8777                                  Ismael
# 2766                                   Lucas
# 390                           Demolition Man
# 5913                            Lost Embrace
# 8412      Evangelion: 3.0 You Can (Not) Redo
# 7927                   Underworld: Awakening
# 7255    Evangelion: 1.0: You Are (Not) Alone
# 3014                                  Shower
# 6343                             Ultraviolet
# 5462                           Before Sunset
# Name: title, dtype: object

# %%
get_recommendations('My Neighbor Totoro').head(10)
# Out:
# 3494    Final Fantasy: The Spirits Within
# 7719                      Red Riding Hood
# 5733                         The Landlord
# 8786                          Poltergeist
# 7730                            Insidious
# 4937                 What's New Pussycat?
# 8171                      Our Little Girl
# 3776                       Female Trouble
# 1588             The Cat from Outer Space
# 1212                         Fathers' Day
# Name: title, dtype: object

# %%
get_recommendations('Spirited Away').head(10)
# Out:
# 450                                  North
# 3744    I Never Promised You a Rose Garden
# 674                                Matilda
# 6858             The Spiderwick Chronicles
# 6383                            Hard Candy
# 6213                            Mirrormask
# 3852             Jimmy Neutron: Boy Genius
# 8853       Zenon: Girl of the 21st Century
# 648                               Daylight
# 4585                    Friends and Family
# Name: title, dtype: object

# %%
get_recommendations('The Godfather').head(10)
# Out:
# 967      The Godfather: Part II
# 8359                 The Family
# 3499                       Made
# 4184         Johnny Dangerously
# 29               Shanghai Triad
# 5651                       Fury
# 2403             American Movie
# 1574    The Godfather: Part III
# 4209                    8 Women
# 2150              Summer of Sam
# Name: title, dtype: object

# %% [markdown]
# **Kết quả:** Kết quả không mấy tự hào, như dự đoán, bởi vì chỉ kết hợp overview và tagline, nên kết quả cho ra chỉ có ích đối với 1 số phim có cùng series

# %% [markdown]
# ## Mô hình gợi ý phim dựa trên nội dung (2):
# Từ kết quả đã đạt được, có thể thấy, nó còn quá đơn sơ và chưa thể sử dụng.
# Chính vì thế, tiếp theo chúng ta cần kết hợp bộ dữ liệu `movies_metadata.csv` với các bộ dữ liệu khác `keywords.csv` và `credits.csv` để lấy keywords, diễn viên chính, và đạo diễn, làm feature cho huấn luyện mô hình.

# %%
keywords = pd.read_csv('input_data/keywords.csv')
credits =pd.read_csv('input_data/credits.csv')

# %%
keywords['id'] = keywords['id'].astype('int')
credits['id'] = credits['id'].astype('int')

# %%
smd.shape
# Out:
# (9053, 10)

# %%
smd = smd.merge(credits, on='id')
smd = smd.merge(keywords, on ='id')
smd.shape
# Out:
# (9071, 13)

# %%
smd.isnull().sum()
# Out:
# id              0
# title           0
# overview        0
# tagline         0
# genres          0
# vote_count      0
# vote_average    0
# popularity      0
# year            0
# description     0
# cast            0
# crew            0
# keywords        0
# dtype: int64

# %%
smd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9071 entries, 0 to 9070
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9071 non-null   int32
#  1   title         9071 non-null   object
#  2   overview      9071 non-null   object
#  3   tagline       9071 non-null   object
#  4   genres        9071 non-null   object
#  5   vote_count    9071 non-null   float64
#  6   vote_average  9071 non-null   float64
#  7   popularity    9071 non-null   object
#  8   year          9071 non-null   object
#  9   description   9071 non-null   object
#  10  cast          9071 non-null   object
#  11  crew          9071 non-null   object
#  12  keywords      9071 non-null   object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 886.0+ KB

# %% [markdown]
# Thấy rằng số hàng là 9071, nhiều hơn so với trước khi merge, vậy nên chắc chắn có trùng lặp ID. Chúng ta sẽ clean lại như sau

# %%
# Xác định các dòng bị lặp dựa trên cột 'id'
duplicate_rows = smd[smd.duplicated(subset=['id'], keep='first')]
# Lấy danh sách các id trùng lặp
duplicate_ids = duplicate_rows['id'].unique()
# Loại bỏ các dòng bị lặp từ DataFrame
smd = smd.drop_duplicates(subset=['id'], keep=False)
# In ra số hàng của DataFrame đã làm sạch
smd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9035 entries, 0 to 9070
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9035 non-null   int32
#  1   title         9035 non-null   object
#  2   overview      9035 non-null   object
#  3   tagline       9035 non-null   object
#  4   genres        9035 non-null   object
#  5   vote_count    9035 non-null   float64
#  6   vote_average  9035 non-null   float64
#  7   popularity    9035 non-null   object
#  8   year          9035 non-null   object
#  9   description   9035 non-null   object
#  10  cast          9035 non-null   object
#  11  crew          9035 non-null   object
#  12  keywords      9035 non-null   object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 952.9+ KB

# %% [markdown]
# Bây giờ ta đã có diễn viên chính, thể loại, đoàn làm phim trong cùng 1 dataframe:
#
# **1. Đoàn làm phim:** Chủ yếu quan tâm đến đạo diễn, nên chúng ta sẽ làm một chút tiền xử lý.
#
# **2. Diễn viên chính:** Chúng ta sẽ chỉ mong muốn lấy ra những diễn viên chính, mỗi bộ phim có số lượng diễn viên chính (hoặc phụ, nhưng có vai trò lớn) không xác định được, nhưng có lẽ con số 3 sẽ còn số phù hợp, chúng ta sẽ lấy ra 3 diễn viên đầu trong từ điển.

# %%
#tương tự bước trên, literal_eval để đưa các trường này về dạng dictionary chính thức
smd['cast'] = smd['cast'].apply(literal_eval)
smd['crew'] = smd['crew'].apply(literal_eval)
smd['keywords'] = smd['keywords'].apply(literal_eval)
smd['cast_size'] = smd['cast'].apply(lambda x: len(x))
smd['crew_size'] = smd['crew'].apply(lambda x: len(x))

# %%
smd['crew_size'].value_counts().sort_index()
# Out:
# crew_size
# 0       14
# 1      276
# 2      548
# 3      510
# 4      311
#       ...
# 228      1
# 242      1
# 244      1
# 338      1
# 435      1
# Name: count, Length: 178, dtype: int64

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
smd['director'] = smd['crew'].apply(get_director)
smd['cast'] = smd['cast'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
smd['cast'] = smd['cast'].apply(lambda x: x[:3] if len(x) >=3 else x)
smd['keywords'] = smd['keywords'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
smd['cast'].iloc[0:3]
# Out:
# 0               [Tom Hanks, Tim Allen, Don Rickles]
# 1    [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2        [Walter Matthau, Jack Lemmon, Ann-Margret]
# Name: cast, dtype: object

# %%
smd['keywords'].iloc[0:5]
# Out:
# 0    [jealousy, toy, boy, friendship, friends, riva...
# 1    [board game, disappearance, based on children'...
# 2    [fishing, best friend, duringcreditsstinger, o...
# 3    [based on novel, interracial relationship, sin...
# 4    [baby, midlife crisis, confidence, aging, daug...
# Name: keywords, dtype: object

# %%
smd['director'].iloc[0:5]
# Out:
# 0      John Lasseter
# 1       Joe Johnston
# 2      Howard Deutch
# 3    Forest Whitaker
# 4      Charles Shyer
# Name: director, dtype: object

# %%
smd['genres'].iloc[0:5]
# Out:
# 0     [Animation, Comedy, Family]
# 1    [Adventure, Fantasy, Family]
# 2               [Romance, Comedy]
# 3        [Comedy, Drama, Romance]
# 4                        [Comedy]
# Name: genres, dtype: object

# %% [markdown]
# * Để mô hình hoạt động tốt, sẽ tương đối hack não.
#
# * Ở đây, chúng ta sẽ tạo ra 1 "thập cẩm" cho mỗi phim, trong đó chứa thể loại, đạo diễn, diễn viên chính, và từ khoá.
#
# * Sau đó sử dụng __Count Vectorizer__ để tạo 1 __count matrix__
#
# * Các bước còn lại sẽ tương tự như đã làm ở trước đó.

# %% [markdown]
# Các bước chuẩn bị cho nồi "thập cẩm" sẽ tiến hành như sau:
#
# 1. __Loại bỏ khoảng trống và uppercase__ từ tất cả các feature. Để đảm bảo mô hình không nhầm lẫn giữa __Johnny Depp and Johnny Galecki.__
# 2. __Tăng trọng số cho đạo diễn__ bằng cách __lặp lại nó 3 lần__ để nó tương đồng với số diễn viên ta đã chọn, từ đó, trọng số của đạo diễn cũng quan trọng ngang diễn viên chính

# %%
smd['cast'] = smd['cast'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
smd['director'] = smd['director'].astype('str').apply(lambda x: str.lower(x.replace(" ", "")))
smd['director'] = smd['director'].apply(lambda x: [x, x, x])

# %%
smd['director']
# Out:
# 0              [johnlasseter, johnlasseter, johnlasseter]
# 1                 [joejohnston, joejohnston, joejohnston]
# 2              [howarddeutch, howarddeutch, howarddeutch]
# 3        [forestwhitaker, forestwhitaker, forestwhitaker]
# 4              [charlesshyer, charlesshyer, charlesshyer]
#                               ...
# 9066        [greggchampion, greggchampion, greggchampion]
# 9067    [tinusureshdesai, tinusureshdesai, tinusureshd...
# 9068    [ashutoshgowariker, ashutoshgowariker, ashutos...
# 9069              [hideakianno, hideakianno, hideakianno]
# 9070                    [ronhoward, ronhoward, ronhoward]
# Name: director, Length: 9035, dtype: object

# %% [markdown]
# **Keywords**
#
# * Chúng ta sẽ tiền xử lý một chút trước khi đưa vào sử dụng nó
# * Đầu tiên __tính tần xuất xuất hiện của mỗi từ__

# %%
s = smd.apply(lambda x: pd.Series(x['keywords']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'keyword'
s = s.value_counts()
s
# Out:
# keyword
# independent film        602
# woman director          538
# murder                  395
# duringcreditsstinger    327
# based on novel          306
#                        ...
# driving test              1
# derbyshire                1
# worm                      1
# joy                       1
# toyko                     1
# Name: count, Length: 12905, dtype: int64

# %% [markdown]
# * Keywords có tần số trải từ 1 đến 610.
# * Và chúng ta chắc chắn không cần những keywords chỉ xuất hiện 1 lần
# * Cuối cùng thì, chúng ta sẽ bình thường hoá các từ về dạng gốc của nó VD: __Dogs__ sẽ đưa về __Dog__.

# %%
s = s[s > 1]

# %%
from nltk.stem.snowball import SnowballStemmer
# Just an example
stemmer = SnowballStemmer('english')
stemmer.stem('dogs')
# Out:
# 'dog'

# %%
def filter_keywords(x):
    words = []
    for i in x:
        if i in s:
            words.append(i)
    return words

# %%
smd['keywords'] = smd['keywords'].apply(filter_keywords)
smd['keywords'] = smd['keywords'].apply(lambda x: [stemmer.stem(i) for i in x])
smd['keywords'] = smd['keywords'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])

# %%
smd['soup'] = smd['keywords'] + smd['cast'] + smd['director'] + smd['genres']
smd['soup'] = smd['soup'].apply(lambda x: ' '.join(x))
smd['soup'].iloc[0:5]
# Out:
# 0    jealousi toy boy friendship friend rivalri boy...
# 1    boardgam disappear basedonchildren'sbook newho...
# 2    fish bestfriend duringcreditssting waltermatth...
# 3    basedonnovel interracialrelationship singlemot...
# 4    babi midlifecrisi confid age daughter motherda...
# Name: soup, dtype: object

# %%
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0.0000000001, stop_words='english')
count_matrix = count.fit_transform(smd['soup'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim[0]
# Out:
# array([1.        , 0.02441931, 0.02738955, ..., 0.        , 0.        ,
#        0.        ])

# %%
#đánh lại chỉ mục cho dataframe
smd = smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])

# %%
indices
# Out:
# title
# Toy Story                                                0
# Jumanji                                                  1
# Grumpier Old Men                                         2
# Waiting to Exhale                                        3
# Father of the Bride Part II                              4
#                                                       ...
# The Last Brickmaker in America                        9030
# Rustom                                                9031
# Mohenjo Daro                                          9032
# Shin Godzilla                                         9033
# The Beatles: Eight Days a Week - The Touring Years    9034
# Length: 9035, dtype: int64

# %%
smd = smd.drop(columns=['index'])

# %%
smd.transpose()
# Out:
#                                                            0     \
# id                                                          862
# title                                                 Toy Story
# overview      Led by Woody, Andy's toys live happily in his ...
# tagline
# genres                              [Animation, Comedy, Family]
# vote_count                                               5415.0
# vote_average                                                7.7
# popularity                                            21.946943
# year                                                       1995
# description   Led by Woody, Andy's toys live happily in his ...
# cast                           [tomhanks, timallen, donrickles]
# crew          [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# keywords      [jealousi, toy, boy, friendship, friend, rival...
# cast_size                                                    13
# crew_size                                                   106
# director             [johnlasseter, johnlasseter, johnlasseter]
# soup          jealousi toy boy friendship friend rivalri boy...
#
#                                                            1     \
# id                                                         8844
# title                                                   Jumanji
# overview      When siblings Judy and Peter discover an encha...
# tagline               Roll the dice and unleash the excitement!
# genres                             [Adventure, Fantasy, Family]
# vote_count                                               2413.0
# vote_average                                                6.9
# popularity                                            17.015539
# year                                                       1995
# description   When siblings Judy and Peter discover an encha...
# cast                [robinwilliams, jonathanhyde, kirstendunst]
# crew          [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# keywords      [boardgam, disappear, basedonchildren'sbook, n...
# cast_size                                                    26
# crew_size                                                    16
# director                [joejohnston, joejohnston, joejohnston]
# soup          boardgam disappear basedonchildren'sbook newho...
#
#                                                            2     \
# id                                                        15602
# title                                          Grumpier Old Men
# overview      A family wedding reignites the ancient feud be...
# tagline       Still Yelling. Still Fighting. Still Ready for...
# genres                                        [Romance, Comedy]
# vote_count                                                 92.0
# vote_average                                                6.5
# popularity                                              11.7129
# year                                                       1995
# description   A family wedding reignites the ancient feud be...
# cast                   [waltermatthau, jacklemmon, ann-margret]
# crew          [{'credit_id': '52fe466a9251416c75077a89', 'de...
# keywords                 [fish, bestfriend, duringcreditssting]
# cast_size                                                     7
# crew_size                                                     4
# director             [howarddeutch, howarddeutch, howarddeutch]
# soup          fish bestfriend duringcreditssting waltermatth...
#
#                                                            3     \
# id                                                        31357
# title                                         Waiting to Exhale
# overview      Cheated on, mistreated and stepped on, the wom...
# tagline       Friends are the people who let you be yourself...
# genres                                 [Comedy, Drama, Romance]
# vote_count                                                 34.0
# vote_average                                                6.1
# popularity                                             3.859495
# year                                                       1995
# description   Cheated on, mistreated and stepped on, the wom...
# cast             [whitneyhouston, angelabassett, lorettadevine]
# crew          [{'credit_id': '52fe44779251416c91011acb', 'de...
# keywords      [basedonnovel, interracialrelationship, single...
# cast_size                                                    10
# crew_size                                                    10
# director       [forestwhitaker, forestwhitaker, forestwhitaker]
# soup          basedonnovel interracialrelationship singlemot...
#
#                                                            4     \
# id                                                        11862
# title                               Father of the Bride Part II
# overview      Just when George Banks has recovered from his ...
# tagline       Just When His World Is Back To Normal... He's ...
# genres                                                 [Comedy]
# vote_count                                                173.0
# vote_average                                                5.7
# popularity                                             8.387519
# year                                                       1995
# description   Just when George Banks has recovered from his ...
# cast                    [stevemartin, dianekeaton, martinshort]
# crew          [{'credit_id': '52fe44959251416c75039ed7', 'de...
# keywords      [babi, midlifecrisi, confid, age, daughter, mo...
# cast_size                                                    12
# crew_size                                                     7
# director             [charlesshyer, charlesshyer, charlesshyer]
# soup          babi midlifecrisi confid age daughter motherda...
#
#                                                            5     \
# id                                                          949
# title                                                      Heat
# overview      Obsessive master thief, Neil McCauley leads a ...
# tagline                                A Los Angeles Crime Saga
# genres                         [Action, Crime, Drama, Thriller]
# vote_count                                               1886.0
# vote_average                                                7.7
# popularity                                            17.924927
# year                                                       1995
# description   Obsessive master thief, Neil McCauley leads a ...
# cast                        [alpacino, robertdeniro, valkilmer]
# crew          [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# keywords      [robberi, detect, bank, obsess, chase, shoot, ...
# cast_size                                                    65
# crew_size                                                    71
# director                [michaelmann, michaelmann, michaelmann]
# soup          robberi detect bank obsess chase shoot thief h...
#
#                                                            6     \
# id                                                        11860
# title                                                   Sabrina
# overview      An ugly duckling having undergone a remarkable...
# tagline       You are cordially invited to the most surprisi...
# genres                                        [Comedy, Romance]
# vote_count                                                141.0
# vote_average                                                6.2
# popularity                                             6.677277
# year                                                       1995
# description   An ugly duckling having undergone a remarkable...
# cast                   [harrisonford, juliaormond, gregkinnear]
# crew          [{'credit_id': '52fe44959251416c75039da9', 'de...
# keywords      [pari, brotherbrotherrelationship, chauffeur, ...
# cast_size                                                    57
# crew_size                                                    53
# director          [sydneypollack, sydneypollack, sydneypollack]
# soup          pari brotherbrotherrelationship chauffeur long...
#
#                                                            7     \
# id                                                        45325
# title                                              Tom and Huck
# overview      A mischievous young boy, Tom Sawyer, witnesses...
# tagline                                  The Original Bad Boys.
# genres                       [Action, Adventure, Drama, Family]
# vote_count                                                 45.0
# vote_average                                                5.4
# popularity                                             2.561161
# year                                                       1995
# description   A mischievous young boy, Tom Sawyer, witnesses...
# cast          [jonathantaylorthomas, bradrenfro, rachaelleig...
# crew          [{'credit_id': '52fe46bdc3a36847f810f797', 'de...
# keywords                                                     []
# cast_size                                                     7
# crew_size                                                     4
# director                [peterhewitt, peterhewitt, peterhewitt]
# soup          jonathantaylorthomas bradrenfro rachaelleighco...
#
#                                                            8     \
# id                                                         9091
# title                                              Sudden Death
# overview      International action superstar Jean Claude Van...
# tagline                              Terror goes into overtime.
# genres                            [Action, Adventure, Thriller]
# vote_count                                                174.0
# vote_average                                                5.5
# popularity                                              5.23158
# year                                                       1995
# description   International action superstar Jean Claude Van...
# cast          [jean-claudevandamme, powersboothe, dorianhare...
# crew          [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...
# keywords                [terrorist, hostag, explos, vicepresid]
# cast_size                                                     6
# crew_size                                                     9
# director                   [peterhyams, peterhyams, peterhyams]
# soup          terrorist hostag explos vicepresid jean-claude...
#
#                                                            9     ...  \
# id                                                          710  ...
# title                                                 GoldenEye  ...
# overview      James Bond must unmask the mysterious head of ...  ...
# tagline                    No limits. No fears. No substitutes.  ...
# genres                            [Adventure, Action, Thriller]  ...
# vote_count                                               1194.0  ...
# vote_average                                                6.6  ...
# popularity                                            14.686036  ...
# year                                                       1995  ...
# description   James Bond must unmask the mysterious head of ...  ...
# cast                [piercebrosnan, seanbean, izabellascorupco]  ...
# crew          [{'credit_id': '52fe426ec3a36847f801e14b', 'de...  ...
# keywords      [cuba, falselyaccus, secretident, computerviru...  ...
# cast_size                                                    20  ...
# crew_size                                                    46  ...
# director       [martincampbell, martincampbell, martincampbell]  ...
# soup          cuba falselyaccus secretident computervirus se...  ...
#
#                                                            9025  \
# id                                                       373348
# title                                Author: The JT LeRoy Story
# overview      New York magazine’s October 2005 issue sent sh...
# tagline
# genres                                            [Documentary]
# vote_count                                                  9.0
# vote_average                                                6.2
# popularity                                             0.428899
# year                                                       2016
# description   New York magazine’s October 2005 issue sent sh...
# cast                [lauraalbert, brucebenderson, denniscooper]
# crew          [{'credit_id': '5675c8bf92514179db0037b2', 'de...
# keywords                                                     []
# cast_size                                                     6
# crew_size                                                     4
# director          [jefffeuerzeig, jefffeuerzeig, jefffeuerzeig]
# soup          lauraalbert brucebenderson denniscooper jefffe...
#
#                                                            9026  \
# id                                                       338766
# title                                        Hell or High Water
# overview      A divorced dad and his ex-con brother resort t...
# tagline                             Blood always follows money.
# genres                        [Crime, Drama, Thriller, Western]
# vote_count                                               1304.0
# vote_average                                                7.2
# popularity                                            12.565896
# year                                                       2016
# description   A divorced dad and his ex-con brother resort t...
# cast                        [jeffbridges, chrispine, benfoster]
# crew          [{'credit_id': '5547ee489251415605000103', 'de...
# keywords      [desper, texa, bankrobb, brother, shoot, carse...
# cast_size                                                    29
# crew_size                                                    56
# director       [davidmackenzie, davidmackenzie, davidmackenzie]
# soup          desper texa bankrobb brother shoot carsetonfir...
#
#                                                            9027  \
# id                                                       390734
# title                             Kingsglaive: Final Fantasy XV
# overview      The magical kingdom of Lucis is home to the wo...
# tagline                           Kingsglaive: Final Fantasy XV
# genres        [Action, Animation, Adventure, Drama, Fantasy,...
# vote_count                                                201.0
# vote_average                                                6.8
# popularity                                             7.692445
# year                                                       2016
# description   The magical kingdom of Lucis is home to the wo...
# cast                    [goayano, shiorikutsuna, ayumifujimura]
# crew          [{'credit_id': '56fd1a259251415fa3002309', 'de...
# keywords           [fight, cgi, basedonvideogam, warrior, anim]
# cast_size                                                    13
# crew_size                                                     5
# director             [takeshinozue, takeshinozue, takeshinozue]
# soup          fight cgi basedonvideogam warrior anim goayano...
#
#                                                            9028  \
# id                                                       314420
# title                                                      Body
# overview      A night out turns deadly when three girls brea...
# tagline
# genres                                        [Drama, Thriller]
# vote_count                                                 16.0
# vote_average                                                5.0
# popularity                                             6.236714
# year                                                       2015
# description   A night out turns deadly when three girls brea...
# cast              [helenrogers, alexandraturshen, laurenmolina]
# crew          [{'credit_id': '54a218a5925141186000079f', 'de...
# keywords                                              [mansion]
# cast_size                                                     5
# crew_size                                                     4
# director                [robertolsen, robertolsen, robertolsen]
# soup          mansion helenrogers alexandraturshen laurenmol...
#
#                                                            9029  \
# id                                                       390989
# title                              Sharknado 4: The 4th Awakens
# overview      The new installment of the Sharknado franchise...
# tagline       What happens in Vegas, stays in Vegas. Unless ...
# genres                        [Comedy, Horror, Science Fiction]
# vote_count                                                 88.0
# vote_average                                                4.3
# popularity                                             4.574494
# year                                                       2016
# description   The new installment of the Sharknado franchise...
# cast                    [ianziering, tarareid, davidhasselhoff]
# crew          [{'credit_id': '56ffae0cc3a3686ea7001e00', 'de...
# keywords      [sharkattack, sequel, farc, lasvega, creaturef...
# cast_size                                                    76
# crew_size                                                    15
# director      [anthonyc.ferrante, anthonyc.ferrante, anthony...
# soup          sharkattack sequel farc lasvega creaturefeatur...
#
#                                                            9030  \
# id                                                       159550
# title                            The Last Brickmaker in America
# overview      A man must cope with the loss of his wife and ...
# tagline
# genres                                                  [Drama]
# vote_count                                                  1.0
# vote_average                                                7.0
# popularity                                             0.038998
# year                                                       2001
# description   A man must cope with the loss of his wife and ...
# cast                [sidneypoitier, wendycrewson, jayo.sanders]
# crew          [{'credit_id': '544475aac3a36819fb000578', 'de...
# keywords                                           [friendship]
# cast_size                                                     7
# crew_size                                                     2
# director          [greggchampion, greggchampion, greggchampion]
# soup          friendship sidneypoitier wendycrewson jayo.san...
#
#                                                            9031  \
# id                                                       392572
# title                                                    Rustom
# overview      Rustom Pavri, an honourable officer of the Ind...
# tagline       Decorated Officer. Devoted Family Man. Defendi...
# genres                                      [Thriller, Romance]
# vote_count                                                 25.0
# vote_average                                                7.3
# popularity                                             7.333139
# year                                                       2016
# description   Rustom Pavri, an honourable officer of the Ind...
# cast                     [akshaykumar, ileanad'cruz, eshagupta]
# crew          [{'credit_id': '5951baf692514129c4016600', 'de...
# keywords                                            [bollywood]
# cast_size                                                    14
# crew_size                                                    16
# director      [tinusureshdesai, tinusureshdesai, tinusureshd...
# soup          bollywood akshaykumar ileanad'cruz eshagupta t...
#
#                                                            9032  \
# id                                                       402672
# title                                              Mohenjo Daro
# overview      Village lad Sarman is drawn to big, bad Mohenj...
# tagline
# genres                     [Adventure, Drama, History, Romance]
# vote_count                                                 26.0
# vote_average                                                6.7
# popularity                                             1.423358
# year                                                       2016
# description   Village lad Sarman is drawn to big, bad Mohenj...
# cast                     [hrithikroshan, poojahegde, kabirbedi]
# crew          [{'credit_id': '57cd5d3592514179d50018e8', 'de...
# keywords                                            [bollywood]
# cast_size                                                    12
# crew_size                                                    16
# director      [ashutoshgowariker, ashutoshgowariker, ashutos...
# soup          bollywood hrithikroshan poojahegde kabirbedi a...
#
#                                                            9033  \
# id                                                       315011
# title                                             Shin Godzilla
# overview      From the mind behind Evangelion comes a hit la...
# tagline                         A god incarnate. A city doomed.
# genres        [Action, Adventure, Drama, Horror, Science Fic...
# vote_count                                                152.0
# vote_average                                                6.6
# popularity                                             9.285519
# year                                                       2016
# description   From the mind behind Evangelion comes a hit la...
# cast          [hirokihasegawa, yutakatakenouchi, satomiishih...
# crew          [{'credit_id': '560892fa92514177550018b2', 'de...
# keywords       [monster, godzilla, giantmonst, destruct, kaiju]
# cast_size                                                    49
# crew_size                                                    27
# director                [hideakianno, hideakianno, hideakianno]
# soup          monster godzilla giantmonst destruct kaiju hir...
#
#                                                            9034
# id                                                       391698
# title         The Beatles: Eight Days a Week - The Touring Y...
# overview      The band stormed Europe in 1963, and, in 1964,...
# tagline                 The band you know. The story you don't.
# genres                                     [Documentary, Music]
# vote_count                                                 92.0
# vote_average                                                7.6
# popularity                                             7.078301
# year                                                       2016
# description   The band stormed Europe in 1963, and, in 1964,...
# cast                    [paulmccartney, ringostarr, johnlennon]
# crew          [{'credit_id': '57057c6cc3a3680dca000285', 'de...
# keywords                                   [music, documentari]
# cast_size                                                    28
# crew_size                                                     7
# director                      [ronhoward, ronhoward, ronhoward]
# soup          music documentari paulmccartney ringostarr joh...
#
# [17 rows x 9035 columns]

# %% [markdown]
# * Tái sử dụng hàm get_recommendations đã viết trước đó.
# * Điểm tương đồng cosine lần này đã khác nên chắc chắn kết quả cũng khác, nhưng chúng ta sẽ mong muốn nó hoạt động tốt hơn trước.

# %%
get_recommendations('Wolf Children').head(10)
# Out:
# 7712                        Summer Wars
# 8966              The Boy and the Beast
# 6842    The Girl Who Leapt Through Time
# 3140                 Digimon: The Movie
# 2291                         Thumbelina
# 1569                              Bambi
# 215                               Gordy
# 574                           Space Jam
# 1686                 The Secret of NIMH
# 1441                  Quest for Camelot
# Name: title, dtype: object

# %% [markdown]
# Bùm, kết quả hiện tại, ở lần thử đầu tiên đã ấn tượng hơn rất nhiều so với trước
# * Cho ra được các phim cùng thể loại Animation
# * Và cùng đạo diễn Mamoru Hosoda

# %%
get_recommendations('Toy Story').head(10)
# Out:
# 6293                Luxo Jr.
# 2493             Toy Story 2
# 7788                  Cars 2
# 6403                    Cars
# 1854            A Bug's Life
# 8384    Toy Story of Terror!
# 7511             Toy Story 3
# 2722       Creature Comforts
# 3788          Monsters, Inc.
# 1404        Meet the Deedles
# Name: title, dtype: object

# %%
get_recommendations('The Dark Knight').head(10)
# Out:
# 7905         The Dark Knight Rises
# 6125                 Batman Begins
# 6522                  The Prestige
# 2056                     Following
# 7530                     Inception
# 4092                      Insomnia
# 3352                       Memento
# 8478                  Interstellar
# 7541    Batman: Under the Red Hood
# 1107                Batman Returns
# Name: title, dtype: object

# %% [markdown]
# Kết quả đối với phim có diễn viên đóng (thay vì diễn viên lồng tiếng như Animation) cũng khá oke.

# %% [markdown]
# **Cải tiếp**
#
# * Chúng ta hoàn toàn có thể thử thủ công các tham số, trọng số khác nha ucho mô hình hiện tại, hoặc giới hạn từ khoá >n thay vì >1, cân nhắc đến việc tần suất xuất hiện của các thể loại, vân vân.

# %% [markdown]
# # Mô hình gợi ý phim dựa trên nội dung (3): Thêm độ phổ biến và đánh giá trung bình vào tính toán trọng số

# %% [markdown]
# * Tuy các điểm đánh giá trung bình hay độ phổ biến không hoàn toàn khách quan nhưng nó vẫn có một số giá trị, chúng ta có thể đưa ra 2 sceneries như sau:
# - Đối với phim (cụ thể là người đóng), ở trên Tmdb, các đánh giá này thường khách quan hơn vì có nhiều lượt đánh giá.
# - Đối với những phim hoạt hình (Animation) thường không có nhiều đánh giá, và điểm đánh giá cũng không khách quan, khi đối tượng người xem phổ thông thường không đánh giá cao phim hoạt hình. Thay vào đó, những đánh giá về phim hoạt hình thường khách quan hơn ở những nơi chúng có tham chiếu lẫn nhau như __Myanimelist.net__
#
# * Nhưng dù vậy, chúng ta vẫn nên tạo 1 cơ chế để loại bỏ những phim có đánh giá quá thấp mà sẽ trả về những phim tích cực được đón nhận hơn.

# %% [markdown]
# * Chúng ta sử dụng đánh giá của TMDB để tìm ra Top Các phim.
# * Thông qua 1 công thức tính trọng số như sau:

# %% [markdown]
# $\large Weighted\; Rating (WR) = (\frac{v}{v + m} . R) + (\frac{m}{v + m} . C)$
# ```
# Trong đó,
#     v số lượng đánh giá (votes) cho phim đó
#     m là số lượng vote tối thiểu để bộ phim đạt tiêu chuẩn cho chart
#     R là điểm số đánh giá của phim
#     C là điểm số đánh giá trung bình cho cả tệp
# ```

# %%
vote_counts = smd[smd['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = smd[smd['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
m = vote_counts.quantile(0.60)

# %%
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
def improved_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    
    movies = smd.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year']]
    
    qualified = movies[(movies['vote_count'] >= m) & (movies['vote_count'].notnull()) & 
                       (movies['vote_average'].notnull())]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    qualified['wr'] = qualified.apply(weighted_rating, axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(10)
    return qualified

# %%
improved_recommendations('Wolf Children')
# Out:
#                                 title  vote_count  vote_average  year  \
# 2137                           Tarzan        1715             7  1999
# 828             The Fox and the Hound         884             7  1981
# 6842  The Girl Who Leapt Through Time         435             7  2006
# 5906                  The Cat Returns         364             7  2002
# 8966            The Boy and the Beast         304             7  2015
# 7712                      Summer Wars         265             7  2009
# 1686               The Secret of NIMH         186             7  1982
# 1569                            Bambi        1450             6  1942
# 574                         Space Jam        1335             6  1996
# 6441                    Monster House         912             6  2006
#
#             wr
# 2137  6.909922
# 828   6.837947
# 6842  6.714830
# 5906  6.675894
# 8966  6.633619
# 7712  6.599679
# 1686  6.507207
# 1569  5.992195
# 574   5.991593
# 6441  5.988263

# %%
improved_recommendations('The Dark Knight')
# Out:
#                            title  vote_count  vote_average  year        wr
# 7530                   Inception       14075             8  2010  7.977195
# 8478                Interstellar       11187             8  2014  7.971389
# 6522                The Prestige        4510             8  2006  7.930447
# 3352                     Memento        4168             8  2000  7.924946
# 7905       The Dark Knight Rises        9263             7  2012  6.982107
# 6125               Batman Begins        7511             7  2005  6.978018
# 7541  Batman: Under the Red Hood         459             7  2010  6.725959
# 2056                   Following         363             7  1998  6.675269
# 7875            Batman: Year One         255             7  2011  6.589939
# 1107              Batman Returns        1706             6  1992  5.993268

# %% [markdown]
# Kết quả cho tới hiện tại là khá hài lòng, cảm nhận cá nhân của tôi cho thấy rằng chúng rất phù hợp với tôi. Tuy nhiên đó chưa phải tất cả, chúng ta sẽ sang phần tiếp theo để xây dựng một mô hình gợi ý dựa trên bộ lọc cộng tác

# %% [markdown]
# # Mô hình gợi ý dựa trên bộ lọc cộng tác (Collaborative Filtering)

# %% [markdown]
# **Mô hình gợi ý dựa trên nội dung có những nhược điểm chí mạng**
#
# * Nó chỉ có thể gợi ý dựa trên 1 phim cụ thể.
# * Không có tính cá nhân hoá cho từng user, nên nếu các user khác nhau thực hiện cùng 1 query, sẽ tả về kết quả hoàn toàn khác nhau.
# * Tuy không thể nói bộ lọc cộng tác sẽ giải quyết hoàn toàn những nhược điểm trên, nhưng vẫn sẽ có tính cá nhân hoá lớn.

# %% [markdown]
# **Về bộ lọc cộng tác**
#
# * Ý tưởng khái quát của nó là việc dựa trên những người dùng đã cùng xem phim đó, và họ cũng xem phim A, B, C để gợi ý cho người dùng khác.
# * Chúng ta sẽ sử dụng thư viện Surpire, vì nó đã cung cấp thuật toán vô cùng mạnh mẽ như là __Singular Value Decomposition (SVD)__ để tối ưu  RMSE và cho ra dự đoán tốt nhất.

# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate

# %%
#đọc dữ liệu rating của từng user cụ thể
ratings = pd.read_csv('input_data/ratings_small.csv')

# %%
# surprise reader API to read the dataset
reader = Reader()

# %%
#không cần timestamp của tệp dữ liệu vì nó không liên quan
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# %%
svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5)
# Out:
# {'test_rmse': array([0.90150402, 0.89375051, 0.89965584, 0.89111546, 0.89234418]),
#  'test_mae': array([0.69610446, 0.68684753, 0.69368492, 0.68666755, 0.68670042]),
#  'fit_time': (3.295283079147339,
#   2.4235494136810303,
#   1.8990719318389893,
#   2.694979190826416,
#   1.7185406684875488),
#  'test_time': (0.4420192241668701,
#   0.21472954750061035,
#   0.5035631656646729,
#   0.281904935836792,
#   0.14962100982666016)}

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
svd.predict(1, 302)
# Out:
# Prediction(uid=1, iid=302, r_ui=None, est=3.027959149677253, details={'was_impossible': False})

# %% [markdown]
# # Hybrid recommendation system

# %% [markdown]
# * In this section, will try to build a simple hybrid recommender that brings together techniques we have implemented in the content based and collaborative filter based engines. This is how it will work:
#
# * **Input:** User ID and the Title of a Movie
# * **Output:** Similar movies sorted on the basis of expected ratings by that particular user.

# %%
def convert_int(x):
    try:
        return int(x)
    except:
        return np.nan

# %%
#mapping ID dựa trên tmdbID trong links_small.csv
id_map = pd.read_csv('input_data/links_small.csv')[['movieId', 'tmdbId']]
id_map['tmdbId'] = id_map['tmdbId'].apply(convert_int)
id_map.columns = ['movieId', 'id']
id_map = id_map.merge(smd[['title', 'id']], on='id').set_index('title')
id_map
# Out:
#                                                     movieId        id
# title
# Toy Story                                                 1     862.0
# Jumanji                                                   2    8844.0
# Grumpier Old Men                                          3   15602.0
# Waiting to Exhale                                         4   31357.0
# Father of the Bride Part II                               5   11862.0
# ...                                                     ...       ...
# The Last Brickmaker in America                       161944  159550.0
# Rustom                                               162542  392572.0
# Mohenjo Daro                                         162672  402672.0
# Shin Godzilla                                        163056  315011.0
# The Beatles: Eight Days a Week - The Touring Years   163949  391698.0
#
# [9035 rows x 2 columns]

# %%
indices_map = id_map.set_index('id')
indices_map
# Out:
#           movieId
# id
# 862.0           1
# 8844.0          2
# 15602.0         3
# 31357.0         4
# 11862.0         5
# ...           ...
# 159550.0   161944
# 392572.0   162542
# 402672.0   162672
# 315011.0   163056
# 391698.0   163949
#
# [9035 rows x 1 columns]

# %%
def hybrid(userId, title):
    idx = indices[title]
    tmdbId = id_map.loc[title]['id']
    movie_id = id_map.loc[title]['movieId']
    sim_scores = list(enumerate(cosine_sim[int(idx)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    movies = smd.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year', 'id']]
    movies['est'] = movies['id'].apply(lambda x: svd.predict(userId, indices_map.loc[x]['movieId']).est)
    movies = movies.sort_values('est', ascending=False)
    return movies.head(10)

# %%
hybrid(1, 'Castle in the Sky')
# Out:
#                                    title  vote_count  vote_average  year  \
# 2396                   Princess Mononoke      2041.0           8.2  1997
# 6010                Howl's Moving Castle      2049.0           8.2  2004
# 4212                       Spirited Away      3968.0           8.3  2001
# 4391                  My Neighbor Totoro      1730.0           8.0  1988
# 5830                         Porco Rosso       563.0           7.6  1992
# 520                              Aladdin      3495.0           7.4  1992
# 4975  Nausicaä of the Valley of the Wind       808.0           7.7  1984
# 5808             Kiki's Delivery Service       768.0           7.6  1989
# 7102                               Ponyo       953.0           7.5  2008
# 8336                      The Wind Rises       720.0           7.7  2013
#
#           id       est
# 2396     128  3.353484
# 6010    4935  3.300827
# 4212     129  3.275309
# 4391    8392  3.247620
# 5830   11621  3.093632
# 520      812  3.072665
# 4975      81  3.058591
# 5808   16859  3.054984
# 7102   12429  3.029469
# 8336  149870  2.968567

# %%
hybrid(1, 'The Girl Who Leapt Through Time')
# Out:
#                                    title  vote_count  vote_average  year  \
# 8342                          About Time      2140.0           7.8  2013
# 5905     Ghost in the Shell 2: Innocence       230.0           7.3  2004
# 8254                       Wolf Children       483.0           8.0  2012
# 3857                         Little Otik        33.0           7.2  2001
# 7544                          Mr. Nobody      1616.0           7.9  2009
# 1030                   Somewhere in Time       104.0           7.1  1980
# 8671  Doctor Who: The Time of the Doctor        61.0           8.4  2013
# 5883             Blood: The Last Vampire        76.0           6.6  2000
# 7712                         Summer Wars       265.0           7.4  2009
# 5862               The End of Evangelion       124.0           8.1  1997
#
#           id       est
# 8342  122906  3.109470
# 5905   12140  3.006105
# 8254  110420  2.952218
# 3857   18939  2.937799
# 7544   31011  2.873858
# 1030   16633  2.841844
# 8671  282848  2.808269
# 5883     919  2.791845
# 7712   28874  2.779248
# 5862   18491  2.751595

# %%
import pickle

# Xuất các DataFrame ra tệp pickle
smd.to_pickle('AI_Dump/smd.pkl')
indices.to_pickle('AI_Dump/indices.pkl')
id_map.to_pickle('AI_Dump/id_map.pkl')
indices_map.to_pickle('AI_Dump/indices_map.pkl')

# Xuất ma trận cosine_sim ra tệp numpy
np.save('AI_Dump/cosine_sim.npy', cosine_sim)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pickle
#       3 # Xuất các DataFrame ra tệp pickle
# ----> 4 smd.to_pickle('processed_data/smd.pkl')
#       5 indices.to_pickle('processed_data/indices.pkl')
#       6 id_map.to_pickle('processed_data/id_map.pkl')
#
# NameError: name 'smd' is not defined

# %%
with open('processed_data/svd_model.pkl', 'wb') as f:
    pickle.dump(svd, f)

# %%
user_ids = ratings['userId'].unique()
np.save('AI_Dump/user_ids.npy', user_ids)
